# %% [markdown]
# ### Imports

# %%
import sys
import os
from pathlib import Path

# %%
helper_path = os.path.join(Path.cwd(), 'helper.py')
sys.path.append(str(helper_path))
import helper

# %% [markdown]
# ### Paths

# %%
src_folder = Path.cwd()
root_folder = src_folder.parent
dataset_folder = os.path.join(root_folder, 'dataset')
models_folder = os.path.join(root_folder, 'models')

baseline_folder = os.path.join(models_folder, 'baselines')

# %% [markdown]
# ### Set model to evaluate

# %%
model_type = 'efficientnet' # alexnet # resnet # vgg16 # densenet # efficientnet

# %%
log_folder = os.path.join(baseline_folder, model_type, 'log')
result_folder = os.path.join(baseline_folder, model_type, 'results')

# %% [markdown]
# ### Reading event files

# %%
scalar_tags = helper.list_scalar_tags(log_folder)
# Out:
# Available Scalar Tags:
# Train/Loss
# Train/Accuracy
# Train/Learning Rate
# Validation/Loss
# Validation/Accuracy

# %%
all_metrics = helper.extract_all_metrics(log_folder)
loss_accuracy_metrics = helper.extract_loss_and_accuracy(all_metrics)

# %% [markdown]
# ### Plot loss and accuracy

# %%
helper.plot_loss(loss_accuracy_metrics, result_folder)
helper.plot_accuracy(loss_accuracy_metrics, result_folder)

# %% [markdown]
# ### Learning Rate

# %%
helper.plot_scalar_metric(log_folder, 'Train/Learning Rate', 'Learning Rate', result_folder)

# %% [markdown]
# ### Compare all models

# %%
model_types = ['alexnet', 'resnet', 'vgg16', 'densenet', 'efficientnet'] 
result_folder = os.path.join(baseline_folder, 'comparison_results')

# %%
helper.compare_models(baseline_folder, model_types, result_folder)
